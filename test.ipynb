# %%
import requests
from bs4 import BeautifulSoup

BASE_URL = "https://www.occ.gov"

response = requests.get(BASE_URL)
soup = BeautifulSoup(response.text, 'html.parser')
spotlight = soup.select(".occgov-card-group__spotlight .usa-card__body a")
news = soup.select(".occgov-card-group__updates a")
publications = soup.select(".usa-card-group .usa-card__body a")

# for item in spotlight:
#     print(item.text)
#     print(BASE_URL + item['href'])
#     print()

# for item in news:
#     print(item.text)
#     print(BASE_URL + item['href'])
#     print()

for item in publications:
    print(item.text)
    print(BASE_URL + item['href'])
    print()
# Out:
# Acting Comptroller Discusses Vital Work of International Data Hub
# https://www.occ.gov/news-issuances/news-releases/2023/nr-occ-2023-111.html
#
# OCC Releases Bank Supervision Operating Plan for Fiscal Year 2024
# https://www.occ.gov/news-issuances/news-releases/2023/nr-occ-2023-109.html
#
# Agencies Extend Favorable CRA Consideration of Revitalization Activities in Certain Disaster Areas Affected by Hurricane Maria
# https://www.occ.gov/news-issuances/news-releases/2023/nr-ia-2023-105.html
#
# Monica Fuentes Freas Named Deputy Comptroller for Large Bank Supervision
# https://www.occ.gov/news-issuances/news-releases/2023/nr-occ-2023-113.html
#
# OCC Releases CRA Evaluations for 28 National Banks and Federal Savings Associations
# https://www.occ.gov/news-issuances/news-releases/2023/nr-occ-2023-112.html
#
# Acting Comptroller Discusses Vital Work of International Data Hub
# https://www.occ.gov/news-issuances/news-releases/2023/nr-occ-2023-111.html
#
# ...

# %%
import smtplib
from email.message import EmailMessage
import os
import logging
from dotenv import load_dotenv

load_dotenv()

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def send_email_via_gmail(subject, body, recipient_email):
    msg = EmailMessage()
    msg.set_content(body)
    msg['Subject'] = subject
    msg['From'] = 'stephenisalertingyou@gmail.com'
    msg['To'] = recipient_email

    # Use environment variable to get password
    password = os.environ.get('APP_PW')
    sending_email = "stephenisalertingyou@gmail.com"

    try:
        with smtplib.SMTP("smtp.gmail.com", 587) as server:
            server.starttls()
            server.login(sending_email, password)
            server.send_message(msg)
            server.quit()
    except Exception as e:
        logging.error(f"Unable to send email. Error: {e}")

body = "This is a test email from Python."
subject = "Test email from Python"
recipient_email = "stephenwgreer@gmail.com"

send_email_via_gmail(subject, body, recipient_email)

# %%
import smtplib
from email.message import EmailMessage
import os
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def send_email_via_gmail(subject, body, recipient_email):
    msg = EmailMessage()
    msg.set_content(body)
    msg['Subject'] = subject
    msg['From'] = 'stephenisalertingyou@gmail.com'
    msg['To'] = recipient_email

    # Use environment variable to get password
    password = os.environ.get('APP_PW')

    try:
        with smtplib.SMTP('smtp.gmail.com', 587) as server:
            server.starttls()
            server.login('stephenisalertingyou@gmail.com', password)
            server.send_message(msg)
    except Exception as e:
        logging.error(f"Unable to send email. Error: {e}")

body = "This is a test email from Python."
subject = "Test email from Python"
recipient_email = "stephenwgreer@gmail.com"

send_email_via_gmail(subject, body, recipient_email)
